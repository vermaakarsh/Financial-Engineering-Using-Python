# %% [markdown]
# ## 1. Setting Up the Environment
# ### Python Installation: Step-by-step instructions on installing Python.
# Installing Required Libraries:
# ```python
# pip install yfinance pandas matplotlib seaborn numpy
# ```
#
# - Importing Libraries: Import all necessary libraries for data analysis.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 2.  Fetching Data from Yahoo Finance
# ### Basic Stock Data Retrieval:
# - Using yfinance to fetch stock data:

# %%
stock = yf.Ticker('Tatamotors.NS')

# %% [markdown]
# - to fetch historical data
# - Period: Duration like `'1d', '1mo', '1y',`
# - Interval: Data frequency like `'1m', '5m', '1d'.`

# %%
data = stock.history(period='1y')
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-10-18 00:00:00+05:30  656.573853  670.181884  651.788631  666.443420
# 2023-10-19 00:00:00+05:30  660.910514  670.231725  656.573860  666.742493
# 2023-10-20 00:00:00+05:30  664.599128  674.319132  658.468023  661.159729
# 2023-10-23 00:00:00+05:30  661.608363  665.197263  643.015713  645.358459
# 2023-10-25 00:00:00+05:30  648.000341  649.894521  634.093245  635.887695
# ...                               ...         ...         ...         ...
# 2024-10-14 00:00:00+05:30  930.000000  940.000000  925.349976  928.250000
# 2024-10-15 00:00:00+05:30  932.950012  935.349976  913.000000  917.299988
# 2024-10-16 00:00:00+05:30  917.049988  923.000000  900.000000  907.450012
# 2024-10-17 00:00:00+05:30  914.950012  914.950012  890.049988  891.599976
# 2024-10-18 00:00:00+05:30  894.299988  917.700012  886.799988  910.150024
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# ## Basic Statistics:
# Calculating mean, median, standard deviation, and other statistics.

# %%
data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count   246.000000   246.000000   246.000000   246.000000  2.460000e+02
# mean    915.520905   924.827378   902.946577   913.455597  1.219318e+07
# std     135.719070   137.469313   132.932798   135.150406  7.831697e+06
# min     628.061827   631.850130   619.936901   624.622437  3.279829e+06
# 25%     810.212237   816.492840   802.635640   810.748108  7.665188e+06
# 50%     960.018690   966.941072   946.578909   957.822449  1.024358e+07
# 75%    1004.537169  1011.795570   989.836635  1002.462479  1.345313e+07
# max    1167.000000  1179.000000  1145.300049  1161.849976  5.981103e+07
#
#         Dividends  Stock Splits
# count  246.000000         246.0
# mean     0.012195           0.0
# std      0.191273           0.0
# min      0.000000           0.0
# 25%      0.000000           0.0
# 50%      0.000000           0.0
# 75%      0.000000           0.0
# max      3.000000           0.0

# %% [markdown]
# ### Visualizing Stock Price Movements:
# - Line Chart for historical price:

# %%
plt.figure(figsize=(10,5))
plt.plot(data['Close'], label='Closing Price')
plt.title('Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ### Get all company info

# %%
stock.info
# Out:
# {'address1': 'Ahura Centre',
#  'address2': '4th Floor 82 Mahakali Caves Road, MIDC Andheri (East)',
#  'city': 'Mumbai',
#  'zip': '400 093',
#  'country': 'India',
#  'phone': '91 22 6240 7101',
#  'website': 'https://www.tatamotors.com',
#  'industry': 'Auto Manufacturers',
#  'industryKey': 'auto-manufacturers',
#  'industryDisp': 'Auto Manufacturers',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %% [markdown]
# ### Dividends and Splits History

# %%
wipro = yf.Ticker('WIPRO.NS')
wipro.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1996-07-01 00:00:00+05:30   0.006250      0.000000
# 1997-08-04 00:00:00+05:30   0.006250      0.000000
# 1997-10-20 00:00:00+05:30   0.000000      3.000000
# 1998-06-15 00:00:00+05:30   0.011250      0.000000
# 1999-07-05 00:00:00+05:30   0.011250      0.000000
# 1999-09-27 00:00:00+05:30   0.000000      5.000000
# 2000-05-09 00:00:00+05:30   0.011250      0.000000
# 2001-06-18 00:00:00+05:30   0.018750      0.000000
# 2002-06-28 00:00:00+05:30   0.037500      0.000000
# 2003-07-01 00:00:00+05:30   0.037500      0.000000
# 2004-05-06 00:00:00+05:30   1.087500      0.000000
# 2004-06-25 00:00:00+05:30   0.000000      3.000000
# 2005-06-29 00:00:00+05:30   0.562500      0.000000
# 2005-08-22 00:00:00+05:30   0.000000      2.000000
# 2006-06-29 00:00:00+05:30   1.125000      0.000000
# 2007-03-26 00:00:00+05:30   1.125000      0.000000
# 2007-06-28 00:00:00+05:30   0.225000      0.000000
# ...

# %% [markdown]
# ### Get Dividends History only

# %%
wipro.dividends
# Out:
# Date
# 1996-07-01 00:00:00+05:30    0.006250
# 1997-08-04 00:00:00+05:30    0.006250
# 1998-06-15 00:00:00+05:30    0.011250
# 1999-07-05 00:00:00+05:30    0.011250
# 2000-05-09 00:00:00+05:30    0.011250
# 2001-06-18 00:00:00+05:30    0.018750
# 2002-06-28 00:00:00+05:30    0.037500
# 2003-07-01 00:00:00+05:30    0.037500
# 2004-05-06 00:00:00+05:30    1.087500
# 2005-06-29 00:00:00+05:30    0.562500
# 2006-06-29 00:00:00+05:30    1.125000
# 2007-03-26 00:00:00+05:30    1.125000
# 2007-06-28 00:00:00+05:30    0.225000
# 2007-10-25 00:00:00+05:30    0.450000
# 2008-06-27 00:00:00+05:30    0.900000
# 2009-06-29 00:00:00+05:30    0.900000
# 2010-06-15 00:00:00+05:30    1.349998
# 2011-01-27 00:00:00+05:30    0.750000
# 2011-06-29 00:00:00+05:30    1.500000
# 2012-01-24 00:00:00+05:30    0.750000
# 2012-06-28 00:00:00+05:30    1.500000
# 2013-01-23 00:00:00+05:30    0.750000
# 2013-06-27 00:00:00+05:30    1.875000
# 2014-01-22 00:00:00+05:30    1.125000
# ...

# %% [markdown]
# ### Get Splits history only

# %%
wipro.splits
# Out:
# Date
# 1997-10-20 00:00:00+05:30    3.000000
# 1999-09-27 00:00:00+05:30    5.000000
# 2004-06-25 00:00:00+05:30    3.000000
# 2005-08-22 00:00:00+05:30    2.000000
# 2010-06-15 00:00:00+05:30    1.666667
# 2017-06-13 00:00:00+05:30    2.000000
# 2019-03-06 00:00:00+05:30    1.333333
# Name: Stock Splits, dtype: float64

# %% [markdown]
# ### Get Number of Shares available in market

# %%
wipro.get_shares_full(start="2000-01-01", end=None)
# Out:
# 2017-04-29 00:00:00+05:30    2416800000
# 2017-05-02 00:00:00+05:30    2417769984
# 2017-05-04 00:00:00+05:30    2412950016
# 2017-05-07 00:00:00+05:30    2412950016
# 2017-05-12 00:00:00+05:30    2417669888
#                                 ...
# 2024-10-16 00:00:00+05:30    5225500160
# 2024-10-17 00:00:00+05:30    5226509824
# 2024-10-18 00:00:00+05:30    5225500160
# 2024-10-18 00:00:00+05:30    5226030080
# 2024-10-19 00:00:00+05:30    5226010112
# Length: 1313, dtype: int64

# %% [markdown]
# ### Get calendar events

# %%
wipro.calendar
# Out:
# {'Ex-Dividend Date': datetime.date(2024, 1, 24),
#  'Earnings Date': [datetime.date(2025, 1, 10), datetime.date(2025, 1, 14)],
#  'Earnings High': 5.9,
#  'Earnings Low': 5.19,
#  'Earnings Average': 5.68,
#  'Revenue High': 225547000000,
#  'Revenue Low': 221000000000,
#  'Revenue Average': 223016000000}

# %% [markdown]
# ### Get Income Statement

# %%
wipro.income_stmt
# Out:
#                                                         2024-03-31  \
# Tax Effect Of Unusual Items                           1664172400.0
# Tax Rate For Calcs                                          0.2452
# Normalized EBITDA                                   187046000000.0
# Total Unusual Items                                   6787000000.0
# Total Unusual Items Excluding Goodwill                6787000000.0
# Net Income From Continuing Operation Net Minori...  110452000000.0
# Reconciled Depreciation                              34071000000.0
# Reconciled Cost Of Revenue                          609407000000.0
# EBITDA                                              193833000000.0
# EBIT                                                159762000000.0
# Net Interest Income                                   6926000000.0
# Interest Expense                                     12552000000.0
# Interest Income                                      19478000000.0
# ...

# %% [markdown]
# ### Get Quarterly Income Statement

# %%
wipro.quarterly_income_stmt
# Out:
#                                                             2024-06-30  \
# Tax Effect Of Unusual Items                           403395414.760294
# Tax Rate For Calcs                                            0.244927
# Normalized EBITDA                                        41857000000.0
# Total Unusual Items                                       1647000000.0
# Total Unusual Items Excluding Goodwill                    1647000000.0
# Net Income From Continuing Operation Net Minori...       30032000000.0
# Reconciled Depreciation                                            NaN
# Reconciled Cost Of Revenue                              153306000000.0
# EBITDA                                                   43504000000.0
# EBIT                                                     43504000000.0
# Net Interest Income                                       2339000000.0
# Interest Expense                                          3288000000.0
# ...

# %% [markdown]
# ### Get Balance Sheet

# %%
wipro.balance_sheet
# Out:
#                                                       2024-03-31  \
# Treasury Shares Number                                 5952740.0
# Ordinary Shares Number                              5219185506.0
# Share Issued                                        5225138246.0
# Net Debt                                           44513000000.0
# Total Debt                                        164649000000.0
# ...                                                          ...
# Accounts Receivable                               115477000000.0
# Cash Cash Equivalents And Short Term Investments  410492000000.0
# Other Short Term Investments                      313539000000.0
# Cash And Cash Equivalents                          96953000000.0
# Cash Financial                                     96953000000.0
#
#                                                       2023-03-31  \
# Treasury Shares Number                                 9895836.0
# ...

# %% [markdown]
# ### Get quarterly balance sheet

# %%
wipro.quarterly_balance_sheet
# Out:
#                                                       2024-06-30  \
# Treasury Shares Number                                 5952740.0
# Ordinary Shares Number                              5224211465.0
# Share Issued                                        5230164205.0
# Net Debt                                           46296000000.0
# Total Debt                                        168906000000.0
# ...                                                          ...
# Accounts Receivable                               114071000000.0
# Cash Cash Equivalents And Short Term Investments  450618000000.0
# Other Short Term Investments                      352314000000.0
# Cash And Cash Equivalents                          98304000000.0
# Cash Financial                                     98304000000.0
#
#                                                       2023-09-30  \
# Treasury Shares Number                                 7310222.0
# ...

# %% [markdown]
# ### Get cashflow statements

# %%
wipro.cashflow
# Out:
#                                              2024-03-31      2023-03-31  \
# Free Cash Flow                           165706000000.0  115767000000.0
# Repurchase Of Capital Stock             -145173000000.0             0.0
# Repayment Of Debt                       -140617000000.0 -178621000000.0
# Issuance Of Debt                         120500000000.0  161034000000.0
# Issuance Of Capital Stock                    13000000.0      12000000.0
# ...                                                 ...             ...
# Gain Loss On Investment Securities                  NaN             NaN
# Net Foreign Currency Exchange Gain Loss     655000000.0     152000000.0
# Gain Loss On Sale Of PPE                  -2072000000.0     -89000000.0
# Gain Loss On Sale Of Business                       0.0       6000000.0
# Net Income From Continuing Operations    111121000000.0  113665000000.0
#
#                                              2022-03-31      2021-03-31  \
# ...

# %% [markdown]
# ### Get quarterly cashflow statements

# %%
wipro.quarterly_cashflow
# Out:
#                                             2023-06-30     2023-03-31
# Free Cash Flow                           35304000000.0  34283000000.0
# Repayment Of Debt                       -17399000000.0 -62860000000.0
# Issuance Of Debt                         15000000000.0  53684000000.0
# Issuance Of Capital Stock                    2000000.0      2000000.0
# Capital Expenditure                      -2209000000.0  -3015000000.0
# ...                                                ...            ...
# Earnings Losses From Equity Investments     -3000000.0     -4000000.0
# Net Foreign Currency Exchange Gain Loss   -226000000.0  -2495000000.0
# Gain Loss On Sale Of PPE                    78000000.0    141000000.0
# Gain Loss On Sale Of Business                      NaN     -3000000.0
# Net Income From Continuing Operations    28860000000.0  30935000000.0
#
# [61 rows x 2 columns]

# %% [markdown]
# ### Get earnings dates

# %%
wipro.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-10-15 16:00:00+05:30           NaN           NaN          NaN
# 2025-07-17 16:00:00+05:30           NaN           NaN          NaN
# 2025-04-17 16:00:00+05:30           NaN           NaN          NaN
# 2025-01-10 16:00:00+05:30           NaN           NaN          NaN
# 2024-10-17 15:00:00+05:30          5.69          6.12       0.0758
# 2024-07-19 15:00:00+05:30          5.65          5.73       0.0149
# 2024-04-19 17:00:00+05:30          5.29          5.41       0.0221
# 2024-01-12 15:00:00+05:30          5.05          5.15       0.0208
# 2023-10-18 16:00:00+05:30          5.41          5.04      -0.0679
# 2023-07-13 15:00:00+05:30          5.44          5.12      -0.0592
# 2023-04-27 16:00:00+05:30          5.76          5.60      -0.0283

# %% [markdown]
# ## Yahoo_fin
# Yahoo_fin is another completely free open source library similar to yfinance, developed by the author of https://theautomatic.net/.

# %%
pip install yahoo_fin
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yahoo_fin --upgrade
# Out:
# ...
#
# ...

# %%
import yahoo_fin.stock_info as si

# %%
si.get_stats_valuation("Wipro.NS")
# Out:
#                  Unnamed: 0 Current 6/30/2024 9/30/2023 6/30/2023 3/31/2023
# 0                Market Cap   2.87T     2.69T     2.12T     2.13T     2.00T
# 1          Enterprise Value   2.59T     2.44T     1.86T     1.90T     1.80T
# 2              Trailing P/E   25.63     24.73     19.22     18.82     17.64
# 3               Forward P/E   22.94     21.51     18.05     17.27     14.84
# 4  PEG Ratio (5yr expected)    1.87      1.75        --      1.12      1.18
# 5               Price/Sales    3.22      3.04      2.44      2.36      2.27
# 6                Price/Book    3.68      3.59      3.16      2.73      2.65
# 7  Enterprise Value/Revenue    2.91      2.72      2.02      2.10      2.05
# 8   Enterprise Value/EBITDA   13.18     12.61      9.46      9.96      9.70

# %% [markdown]
# ### Get options data

# %%
import yahoo_fin.options as ops

# %%
ops.get_calls("aapl")
# Out:
#           Contract Name Last Trade Date (EDT)  Strike  Last Price     Bid  \
# 0   AAPL241025C00100000     10/4/2024 7:53 PM   100.0      126.51  134.25
# 1   AAPL241025C00105000    10/16/2024 7:28 PM   105.0      126.68  129.85
# 2   AAPL241025C00130000    10/16/2024 7:16 PM   130.0      101.74  104.85
# 3   AAPL241025C00140000    10/18/2024 2:08 PM   140.0       95.79   94.30
# 4   AAPL241025C00145000    10/18/2024 7:23 PM   145.0       90.47   89.20
# 5   AAPL241025C00150000    10/18/2024 7:23 PM   150.0       85.51   84.90
# 6   AAPL241025C00155000    10/15/2024 1:30 PM   155.0       78.85   79.90
# 7   AAPL241025C00160000    10/17/2024 4:42 PM   160.0       72.44   74.90
# 8   AAPL241025C00165000    10/18/2024 4:31 PM   165.0       70.20   69.90
# 9   AAPL241025C00170000    10/18/2024 7:53 PM   170.0       65.04   64.90
# 10  AAPL241025C00175000    10/18/2024 7:53 PM   175.0       60.04   59.90
# 11  AAPL241025C00180000    10/18/2024 7:58 PM   180.0       55.20   54.95
# ...

# %%
ops.get_puts("aapl")
# Out:
#           Contract Name Last Trade Date (EDT)  Strike  Last Price    Bid  \
# 0   AAPL241025P00100000     9/20/2024 6:32 PM   100.0        0.01   0.00
# 1   AAPL241025P00105000     10/3/2024 4:09 PM   105.0        0.06   0.00
# 2   AAPL241025P00120000     9/24/2024 1:44 PM   120.0        0.01   0.00
# 3   AAPL241025P00125000    10/11/2024 2:00 PM   125.0        0.02   0.00
# 4   AAPL241025P00130000    10/17/2024 7:37 PM   130.0        0.01   0.00
# 5   AAPL241025P00135000     10/7/2024 7:48 PM   135.0        0.02   0.00
# 6   AAPL241025P00140000    10/11/2024 1:45 PM   140.0        0.01   0.00
# 7   AAPL241025P00145000    10/10/2024 6:34 PM   145.0        0.01   0.00
# 8   AAPL241025P00150000    10/18/2024 7:39 PM   150.0        0.01   0.00
# 9   AAPL241025P00155000     10/4/2024 6:41 PM   155.0        0.03   0.00
# 10  AAPL241025P00160000    10/18/2024 7:39 PM   160.0        0.01   0.00
# 11  AAPL241025P00165000    10/15/2024 3:31 PM   165.0        0.02   0.00
# ...
